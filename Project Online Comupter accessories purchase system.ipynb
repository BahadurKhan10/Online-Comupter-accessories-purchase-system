# %% [markdown]
# # Online Computer Accessories system

# %%
from tkinter import *
from tkinter import ttk
import tkinter.messagebox

#Setting up window
root=Tk()
root.configure(background='grey')
root.geometry('800x550')
root.resizable(0, 0)
root.title("Online Computer Accessories Shopping System")



#-------------------------Setting up the label of Galaxy.pk--------------------
class Galaxypk:
    def __init__(self,master):
        myFrame=Frame(master)
        myFrame.pack()
        self.label = Label(master, text="Galaxy Pk", relief='solid', width=20, bg='grey', fg='white', font=("bold", 25))
        self.label.place(x=240, y=50)

    def getdetails():    
        print("WELCOME TO ONLINE COMPUTER SHOPPING SYSTEM")
        
# -------------------------Declaring all variables---------------------------

var_name = StringVar()
var_order= StringVar()
var_userid = StringVar()
var_sc = StringVar()
var_address = StringVar()
var_card = StringVar()
var_conf = StringVar()
var_contact = StringVar()
var_city = StringVar()
var_payment = StringVar()
        
        
#--------------------------------Setting up the user in gui--------------------------        
class User:
    def __init__(self,master):
        self.label_name = Label(master, text="User Name", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_name.place(x=80, y=130)
        self.entry = Entry(master, textvar=var_name).place(x=240, y=130)
    #CITY
        self.label_city = Label(master, text="City", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_city.place(x=70, y=320)
        self.entry= Entry(master, textvar=var_city).place(x=240, y=320)
    #Contact
        self.label_contact = Label(master, text="Contact", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_contact.place(x=70, y=360)
        self.entry= Entry(master, textvar=var_contact).place(x=240, y=360)
        
    #Credit Card no
        self.label_card = Label(master, text="Credit Card no:", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_card.place(x=445, y=300)
        self.entry=Entry(master, textvar=var_card).place(x=590, y=300)
    #Address
        label_address = Label(master, text="Delivery Address:", width=20, bg='grey', fg='white', font=("bold", 10))
        label_address.place(x=420, y=350)
        self.entry=Entry(master, textvar=var_address).place(x=590, y=350)
        
    #CNIC

        self.label_userid = Label(master, text="CNIC", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_userid.place(x=68, y=180)
        self.entry=Entry(master, textvar=var_userid).place(x=240, y=180)

    
    def addUser(self,user_id,user_name,user_email,user_dob,user_address):
        print("Enter the details of USER you want to ADD:","\nUser ID=",self.user_id,",User name=",self.user_name,",User Email=",self.user_email,",User Date of Birth=",self.user_dob,",User Address=",self.user_address,"\n---------------------------------------------------------------------")
        
    def editUser(self,user_id,user_name,user_email,user_dob,user_address):
        print("Enter the details of User you want to EDIT:","\nUserID=",self.user_id,",User name=",self.user_name,",User Email=",self.user_email,",User Date of Birth=",self.user_dob,",User Address=",self.user_address,"\n---------------------------------------------------------------------")
        
    def deleteUser(self,user_id,user_name,user_email,user_dob,user_address): 
        print("Enter the details of User you want to DELETE:","\nUser ID=",self.user_id,",User name=",self.user_name,",Use Email=",self.user_email,",User Date of Birth=",self.user_dob,",User Address=",self.user_address,"\n---------------------------------------------------------------------")
    
    def searchUser(self,user_id,user_name,user_email,user_dob,user_address): 
        print("Enter the details of User you want to SEARCH:","\nUser ID=",self.user_id,",User name=",self.user_name,",Use Email=",self.user_email,",User Date of Birth=",self.user_dob,",User Address=",self.user_address,"\n---------------------------------------------------------------------")    
        

#-----------------------------Selecting Product------------------------------        
class Product:
    def __init__(self,master):
        self.label_product = Label(master, text="Product", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_product.place(x=390, y=130)
        self.order = ttk.Combobox(master, values=["Mouse", "Keyboard","LCD", "CPU","Graphic Card","Speakers"], textvar=var_order)
        self.order.current(0)
        self.order.place(x=540, y=130)
    

    
    def addProduct(self,product_id,product_type,product_company,product_items):
        print("Enter the Product with Details you want to ADD:","\nProduct ID=",self.product_id,",Product name=",self.product_type,",Product Company name=",self.product_company,",Product Items=",self.product_items,"\n---------------------------------------------------------------------")
        
    def editProduct(self,product_id,product_type,product_company,product_items):
        print("Enter the Product with Details you want to EDIT","\nProduct ID=",self.product_id,",Product name=",self.product_type,",Product Company name=",self.product_company,",Product Items=",self.product_items,"\n---------------------------------------------------------------------")
        
    def deleteProduct(self,product_id,product_type,product_company,product_items): 
        print("Enter the Product with Details you want to DELETE:","\nProduct ID=",self.product_id,",Product name=",self.product_type,",Product Company name=",self.product_company,",Product Items=",self.product_items,"\n---------------------------------------------------------------------")
    
    def searchProduct(self,product_id,product_type,product_company,product_items): 
        print("Enter the Product with Details you want to SEARCH:","\nProduct ID=",self.product_id,",Product name=",self.product_type,",Product Company name=",self.product_company,",Product Items=",self.product_items,"\n---------------------------------------------------------------------")
        
#-----------------------------Shopping Cart-----------------------------
class ShoppingCart:
    def __init__ (self,master):
        self.label_sc = Label(master, text="Discount copun", bg='grey', fg='white', width=20, font=("bold", 10))
        self.label_sc.place(x=390, y=180)
        self.entry= Entry(master, textvar=var_sc).place(x=540, y=180)
    
    def addShoppingCart(self,shopping_cart_id,shopping_cart_name,shopping_cart_type):
        print("Enter the details of Shopping Cart you want to ADD:","\nShopping Cart ID=",self._shopping_cart_id,",Shopping Cart Maker=",self.shopping_cart_name,",Shopping Cart Type=",self.shopping_cart_type,",Id of Customer of this shopping cart=",self.customer_id,"\n---------------------------------------------------------------------")
        
    def editShoppingCart(self,shopping_cart_id,shopping_cart_name,shopping_cart_type):
        print("Enter the details of Shopping Cart you want to EDIT","\nShopping Cart ID=",self._shopping_cart_id,",Shopping Cart Maker=",self.shopping_cart_name,",Shopping Cart Type=",self.shopping_cart_type,",Id of Customer of this shopping cart=",self.customer_id,"\n---------------------------------------------------------------------")
        
    def deleteShoppingCart(self,shopping_cart_id,shopping_cart_name,shopping_cart_type): 
        print("Enter the details of Shopping Cart you want to DELETE:","\nShopping Cart ID=",self._shopping_cart_id,",Shopping Cart Maker=",self.shopping_cart_name,",Shopping Cart Type=",self.shopping_cart_type,",Id of Customer of this shopping cart=",self.customer_id,"\n---------------------------------------------------------------------")
        
    def searchShoppingCart(self,shopping_cart_id,shopping_cart_name,shopping_cart_type): 
        print("Enter the details of Shopping Cart you want to SEARCH:","\nShopping Cart ID=",self._shopping_cart_id,",Shopping Cart Maker=",self.shopping_cart_name,",Shopping Cart Type=",self.shopping_cart_type,",Id of Customer of this shopping cart=",self.customer_id,"\n---------------------------------------------------------------------")


#---------------------------------------PAYMENT-----------------------------------------
class Payment:
    def __init__(self,master):
        self.label_payment= Label(master, text="Payment", width=20, bg='grey', fg='white', font=("bold", 10))
        self.label_payment.place(x=70, y=230)
        self.radiobutton= Radiobutton(master, text="Cash online", variable=var_payment, bg='grey', fg='black', value='Cash Online').place(x=235, y=230)
        self.radiobutton= Radiobutton(master, text="Cash on Delivery", variable=var_payment, bg='grey', fg='black', value='Cash on Delivery').place(x=320,y=230)

    
    def PayPayment(self,transaction_id,payment_amount,payment_date,payment_description):
        print("Enter the details of Payment to Pay:","\nTransation ID=",self.transaction_id,"Customer ID=",self.customer_id,",Payment Amount=",self.payment_amount,",Payment Date=",self.payment_date,"\n---------------------------------------------------------------------")
    def editPayment(self,transaction_id,payment_amount,payment_date,payment_description):
        print("Enter the details of Payment to Pay:","\nTransation ID=",self.transaction_id,"Customer ID=",self.customer_id,",Payment Amount=",self.payment_amount,",Payment Date=",self.payment_date,"\n---------------------------------------------------------------------")
    def deletePayment(self,transaction_id,payment_amount,payment_date,payment_description):
        print("Enter the details of Payment to Pay:","\nTransation ID=",self.transaction_id,"Customer ID=",self.customer_id,",Payment Amount=",self.payment_amount,",Payment Date=",self.payment_date,"\n---------------------------------------------------------------------")
    def searchPayment(self,transaction_id,payment_amount,payment_date,payment_description):
        print("Enter the details of Payment to Pay:","\nTransation ID=",self.transaction_id,"Customer ID=",self.customer_id,",Payment Amount=",self.payment_amount,",Payment Date=",self.payment_date,"\n---------------------------------------------------------------------")
        

#--------------------------CONFIRM ORDER?----------------------------
class Order:
    def __init__(self,master):
        self.label_conf = Label(master, text="Confirm order? ", width=21, bg='grey', fg='white', font=("bold", 10))
        self.label_conf.place(x=445, y=230)
        self.radiobutton= Radiobutton(master, text="Yes", variable=var_conf, bg='grey', fg='black', value='Yes').place(x=480, y=260)
        self.radiobutton= Radiobutton(master, text="No", variable=var_conf, bg='grey', fg='black', value='No').place(x=530, y=260)

    
    def addOrder(self,order_id,order_type,order_description):
        print("Enter the details of order you want to ADD:","\nOrder ID=",self.order_id,",Order Type=",self.order_type,",Order Description=",self.order_description,"\n---------------------------------------------------------------------")
        
    def editOrder(self,order_id,order_type,order_description):
        print("Enter the details of order you want to EDIT","\nOrder ID=",self.order_id,",Order Type=",self.order_type,",Order Description=",self.order_description,"\n---------------------------------------------------------------------")
        
    def deleteOrder(self,order_id,order_type,order_description): 
        print("Enter the details of order you want to DELETE:","\nOrder ID=",self.order_id,",Order Type=",self.order_type,",Order Description=",self.order_description,"\n---------------------------------------------------------------------")
        
    def searchOrder(self,order_id,order_type,order_description): 
        print("Enter the details of order you want to SEARCH:","\nOrder ID=",self.order_id,",Order Type=",self.order_type,",Order Description=",self.order_description,"\n---------------------------------------------------------------------")

#-----------------------------EXCEPTIONAL HANDLING-------------------

def app_status():
    name=var_name.get()
    userid=var_userid.get()
    contact=var_contact.get()
    card=var_card.get()
    address=var_address.get()
    
    
    if name ==(1234567890):
        tkinter.messagebox.showinfo('Message', 'Fill the form correctly')
    elif userid ==('abcdefghijklmnopqrstuvwxyz') or ("ABCDEFGHIJKLMNOPQRSTUVWXYZ"):
        tkinter.messagebox.showinfo('Message', 'Fill the form correctly')
    elif card == ('abcdefghijklmnopqrstuvwxyz') or ("ABCDEFGHIJKLMNOPQRSTUVWXYZ"):
        tkinter.messagebox.showinfo('Message', 'Fill the form correctly')
    elif contact ==('abcdefghijklmnopqrstuvwxyz') or ("ABCDEFGHIJKLMNOPQRSTUVWXYZ"):
        tkinter.messagebox.showinfo('Message', 'Fill the form correctly')
    else:
        tkinter.messagebox.showinfo('Message', 'Order has been Placed, and will be delivered in two days')
    
    
#----------------------------FUNCTION FOR CONTINUE---------------------        
def btn_continue():
    name=var_name
    order=var_order.get()
    userid=var_userid.get()
    shoppingCart=var_sc.get()
    address=var_address.get()
    card=var_card.get()
    confirm=var_conf.get()
    contact=var_contact.get()
    city=var_city.get()
    payment=var_payment.get()
    ask = tkinter.messagebox.askquestion('Message', 'Confirm the order')
    if ask == 'yes':
        if name == '' or userid == '' or contact == ''or card == '' or address=='' or city=='':
            tkinter.messagebox.showinfo('Message', 'Fill the form correctly')
        else:
            app_status()
    else:
        tkinter.messagebox.showinfo('Warning', 'Order has been Cancelled!')
        
#-----------------------------CONITNUE-----------------------      
class Shopping:
    def __init__(self,master):
        self.button=Button(master, text='Continue', width=20, bg='green', fg='white',command=btn_continue).place(x=340, y=430)
   
    def addShopping(self,shopping_ID,shopping_name,shopping_Description):
        print("Enter the details of shopping you want to ADD:","\nShopping ID=",self.shopping_ID,", Shopping name=",self.shopping_name,", Shopping Description=",self.shopping_Description,"\n---------------------------------------------------------------------")
        
    def editShopping(self,shopping_ID,shopping_name,shopping_Description):
        print("Enter the details of shopping you want to EDIT:","\n Shopping ID=",self.shopping_ID,", Shopping name=",self.shopping_name,", Shopping Description=",self.shopping_Description,"\n---------------------------------------------------------------------")
        
    def deleteShopping(self,shopping_ID,shopping_name,shopping_Description): 
        print("Enter the details of shopping you want to DELETE:","\n Shopping ID=",self.shopping_ID,", Shopping name=",self.shopping_name,", Shopping Description=",self.shopping_Description,"\n---------------------------------------------------------------------")
        
    def searchShopping(self,shopping_ID,shopping_name,shopping_Description): 
        print("Enter the details of shopping you want to SEARCH:","\n Shopping ID=",self.shopping_ID,", Shopping name=",self.shopping_name,", Shopping Description=",self.shopping_Description,"\n---------------------------------------------------------------------")


        
b=Galaxypk(root) 
u=User(root)
p=Product(root)
s=ShoppingCart(root)
p=Payment(root)
o=Order(root)
ss=Shopping(root)

root.mainloop()
